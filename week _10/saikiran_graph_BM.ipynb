# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
models = ['Dummy', 'KNN-1', 'KNN-2', 'KNN-3-1', 'KNN-3-2']
stages = ['Dummy', 'KNN Training', 'KNN Prediction', 'KNN Retraining', 'KNN Retrained Prediction']
accuracies = [0.5075, 0.895, 0.963, 0.721, 0.965]
recalls = [0.5327, 0.9045, 0.9061, 1.0, 0.8873]
precisions = [0.5048, 0.8867, 0.9407, 0.4163, 0.913]

# %%
x = np.arange(len(models))

# %%
import matplotlib.pyplot as plt

# Define the stages and corresponding metric values
stages = ['Dummy', 'KNN Training', 'KNN Prediction', 'KNN Retraining', 'KNN Retrained Prediction']
x = range(len(stages))

# Example metric values; replace these with your actual data
accuracies = [0.5, 0.65, 0.68, 0.7, 0.75]
recalls = [0.45, 0.6, 0.63, 0.67, 0.72]
precisions = [0.4, 0.58, 0.61, 0.65, 0.7]

# Set up the plot
plt.figure(figsize=(12, 8))

# Plot each metric
plt.plot(x, accuracies, marker='o', linestyle='-', linewidth=2, label='Accuracy', color='blue')
plt.plot(x, recalls, marker='o', linestyle='-', linewidth=2, label='Recall', color='green')
plt.plot(x, precisions, marker='o', linestyle='-', linewidth=2, label='Precision', color='red')

# Customize the x-axis
plt.xticks(x, stages, rotation=15)
plt.xlabel('Model Training Stage')
plt.ylabel('Score')
plt.title('Model Performance Metrics Across Different Training Stages')

# Add gridlines
plt.grid(True, linestyle='--', alpha=0.7)

# Add a baseline line
plt.axhline(y=0.5, color='gray', linestyle='--', alpha=0.5, label='Baseline')

# Annotate each point with its value
